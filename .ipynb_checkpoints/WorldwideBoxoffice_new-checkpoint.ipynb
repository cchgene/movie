# %%
import re
import time
import json
import pandas as pd
import requests as r
from bs4 import BeautifulSoup

# %%
tStart = time.time()
WorldwideBoxoffice_rowdata = []
for i in range(1,16725,25):  #16722 titles as of Dec 9 2017
    url = "http://www.worldwideboxoffice.com/index.cgi?top={}&start=1900&finish=2017&order=worldwide&keyword=&links=&popups=".format(i)
    resp = r.get(url)
    WorldwideBoxoffice_rowdata.append(resp.text)

with open("WorldwideBoxoffice_rowdata.json", "w") as f:
    jd = json.dumps(WorldwideBoxoffice_rowdata, ensure_ascii=False, indent=4)
    jd.encode("utf-8")
    f.write(jd)
tEnd = time.time()
print(tEnd-tStart)
# Out:
# -680.1489870548248

# %%
# !ls
# Out:
# Agri				Untitled.ipynb
# IGIFT				WorldwideBoxoffice.ipynb
# load_mysql_from_other_ip.ipynb	WorldwideBoxoffice_rowdata.json
# tool

# %%
with open("WorldwideBoxoffice_rowdata.json",'r') as load_f:
    WorldwideBoxoffice_rowdata = json.load(load_f)

# %%
WorldwideBoxoffice_rowdata
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
movies_box = []
for i in range(int(16725/25)):
    soup = BeautifulSoup(WorldwideBoxoffice_rowdata[i], "html5lib")
    a = str(soup.select("pre")[0])
    b = BeautifulSoup(a,"html5lib")
    for movie in str(b.select("body")[0]).split("\n\n")[1].split("\n"):
        temp = {}
        temp["RANK"] = movie.split("  ")[0].strip()

        if 'n/a' in movie.split('$')[0]:
            temp["DOMESTIC"] = 'n/a'
            temp["OVERSEAS"] = movie.split('$')[1].strip()
        elif 'n/a' in movie.split('$')[1]:
            temp["DOMESTIC"] = movie.split('$')[1].split('n/a')[0].strip()
            temp["OVERSEAS"] = 'n/a'
        else:
            temp["DOMESTIC"] = movie.split('$')[1].strip()
            temp["OVERSEAS"] = movie.split('$')[2].strip()

        temp["WORLD"] = movie.split("<cite>")[0].split("$")[-1]


    #     <cite><a href="movie.cgi?title=Star%20Wars%3A%20Episode%20I%20%2D%20The%20Phantom%20Menace&amp;year=1999">Star Wars: Episode I - The Phantom Menace</a></cite> (1999)
        temp["TITLES"] = BeautifulSoup(movie, "html5lib").select("cite > a")[0].text.strip()
        temp["YEAR"] = int(re.findall('</cite> \((\d{4})', movie)[0].strip())
        temp["HREF"] = re.findall('href="(.+)">', movie)[0].strip()

        movies_box.append(temp)
    

        
with open("movies_box_new.json", "w") as f:
    jd = json.dumps(movies_box, ensure_ascii=False, indent=4)
    jd.encode("utf-8")
    f.write(jd)

# %%
df = pd.DataFrame(movies_box)
df
# Out:
#       DOMESTIC                                               HREF OVERSEAS  \
# 0        760.5               movie.cgi?title=Avatar&amp;year=2009   2027.5
# 1        659.3              movie.cgi?title=Titanic&amp;year=1997   1528.1
# 2        936.0  movie.cgi?title=Star%20Wars%3A%20Episode%20VII...   1130.0
# 3        652.3     movie.cgi?title=Jurassic%20World&amp;year=2015   1018.1
# 4        623.4       movie.cgi?title=The%20Avengers&amp;year=2012    896.2
# 5        353.0      movie.cgi?title=Furious%20Seven&amp;year=2015   1163.0
# 6        459.0  movie.cgi?title=Avengers%3A%20Age%20of%20Ultro...    946.4
# 7        225.8  movie.cgi?title=The%20Fate%20of%20the%20Furiou...   1165.9
# 8        381.0  movie.cgi?title=Harry%20Potter%20and%20the%20D...    960.5
# 9        400.7             movie.cgi?title=Frozen&amp;year=2013/I    875.7
# 10       504.0  movie.cgi?title=Beauty%20and%20the%20Beast&amp...    759.5
# 11       409.0   movie.cgi?title=Iron%20Man%20Three&amp;year=2013    806.4
# 12       336.0              movie.cgi?title=Minions&amp;year=2015    827.5
# 13       408.1  movie.cgi?title=Captain%20America%3A%20Civil%2...    745.2
# 14       352.4  movie.cgi?title=Transformers%3A%20Dark%20of%20...    771.4
# 15       377.8  movie.cgi?title=The%20Lord%20of%20the%20Rings%...    742.1
# 16       304.4              movie.cgi?title=Skyfall&amp;year=2012    804.2
# 17       245.4  movie.cgi?title=Transformers%3A%20Age%20of%20E...    858.6
# 18       448.1  movie.cgi?title=The%20Dark%20Knight%20Rises&am...    636.8
# 19       402.5      movie.cgi?title=Jurassic%20Park&amp;year=1993    675.0
# 20       423.3  movie.cgi?title=Pirates%20of%20the%20Caribbean...    642.9
# 21       532.2          movie.cgi?title=Rogue%20One&amp;year=2016    523.9
# 22       415.0      movie.cgi?title=Toy%20Story%203&amp;year=2010    635.7
# 23       241.1  movie.cgi?title=Pirates%20of%20the%20Caribbean...    804.6
# 24       264.5  movie.cgi?title=Despicable%20Me%203&amp;year=2017    766.1
# 25       486.3       movie.cgi?title=Finding%20Dory&amp;year=2016    542.3
# 26       474.5  movie.cgi?title=Star%20Wars%3A%20Episode%20I%2...    552.5
# 27       334.2  movie.cgi?title=Alice%20in%20Wonderland&amp;ye...    691.3
# 28       341.3             movie.cgi?title=Zootopia&amp;year=2016    682.5
# 29       303.0  movie.cgi?title=The%20Hobbit%3A%20An%20Unexpec...    718.1
# ...        ...                                                ...      ...
# 16671      n/a    movie.cgi?title=Green%20is%20Gold&amp;year=2016      0.0
# 16672      n/a  movie.cgi?title=Farewell%20Calm%20Days&amp;yea...      0.0
# 16673      n/a         movie.cgi?title=Ill%C3%A9gal&amp;year=2010      0.0
# 16674      n/a  movie.cgi?title=Gottfried%20Helnwein%20and%20t...      0.0
# 16675      n/a  movie.cgi?title=A%20New%20Day%20in%20Old%20San...      0.0
# 16676      n/a                movie.cgi?title=Uncut&amp;year=2003      0.0
# 16677      n/a  movie.cgi?title=A%20People%20Uncounted&amp;yea...      0.0
# 16678      n/a      movie.cgi?title=%C3%89perdument&amp;year=2016      0.0
# 16679      n/a    movie.cgi?title=A%20Perfect%20Man&amp;year=2013      0.0
# 16680      n/a       movie.cgi?title=Nature%20Calls&amp;year=2012      0.0
# 16681      n/a          movie.cgi?title=Evil%20Cult&amp;year=2003      0.0
# 16682      n/a  movie.cgi?title=Gagsters%3A%20The%20Movie&amp;...      0.0
# 16683      n/a  movie.cgi?title=Boven%20is%20het%20stil&amp;ye...      0.0
# 16684      n/a  movie.cgi?title=Death%20of%20a%20Superhero&amp...      0.0
# 16685      n/a           movie.cgi?title=Algorithms&amp;year=2013      0.0
# 16686      n/a         movie.cgi?title=Trojan%20War&amp;year=1997      0.0
# 16687      n/a       movie.cgi?title=Intervention&amp;year=2007/V      0.0
# 16688      n/a          movie.cgi?title=Playback&amp;year=2012/II      0.0
# 16689      n/a              movie.cgi?title=Satanic&amp;year=2016      0.0
# 16690      n/a  movie.cgi?title=The%20Innocent%20Maleficent&am...      0.0
# 16691      n/a           movie.cgi?title=Alice&amp;year=2016/XIII      0.0
# 16692      n/a             movie.cgi?title=A%C3%AFe&amp;year=2000      0.0
# 16693      n/a  movie.cgi?title=Amy%27s%20Organic%20Garden&amp...      0.0
# 16694      n/a              movie.cgi?title=Legenda&amp;year=2012      0.0
# 16695      n/a  movie.cgi?title=Camping%20Misadventures&amp;ye...      0.0
# 16696      n/a  movie.cgi?title=The%20Colonial%20Parkway%3A%20...      0.0
# 16697      n/a  movie.cgi?title=A%20meg%20nem%20%C3%A9rintett&...      0.0
# 16698      n/a          movie.cgi?title=Detention&amp;year=2010/I      0.0
# 16699      n/a       movie.cgi?title=Meeting%20Evil&amp;year=2012      0.0
# 16700      n/a        movie.cgi?title=Ground%20Zero&amp;year=2000      0.0
#
#                                 RANK  \
# 0                               0001
# 1                               0002
# 2                               0003
# 3                               0004
# 4                               0005
# 5                               0006
# 6                               0007
# 7      <b><font color="#17FF17">0008
# 8                               0009
# 9                               0010
# 10     <b><font color="#17FF17">0011
# 11                              0012
# 12                              0013
# 13                              0014
# 14                              0015
# 15                              0016
# 16                              0017
# 17                              0018
# 18                              0019
# 19                              0020
# 20                              0021
# 21                              0022
# 22                              0023
# 23                              0024
# 24     <b><font color="#17FF17">0025
# 25                              0026
# 26                              0027
# 27                              0028
# 28                              0029
# 29                              0030
# ...                              ...
# 16671                          16672
# 16672                          16673
# 16673                          16674
# 16674                          16675
# 16675                          16676
# 16676                          16677
# 16677                          16678
# 16678                          16679
# 16679                          16680
# 16680                          16681
# 16681                          16682
# 16682                          16683
# 16683                          16684
# 16684                          16685
# 16685                          16686
# 16686                          16687
# 16687                          16688
# 16688                          16689
# 16689                          16690
# 16690                          16691
# 16691                          16692
# 16692                          16693
# 16693                          16694
# 16694                          16695
# 16695                          16696
# 16696                          16697
# 16697                          16698
# 16698                          16699
# 16699                          16700
# 16700                          16701
#
#                                                   TITLES      WORLD  YEAR
# 0                                                 Avatar   2788.0    2009
# 1                                                Titanic   2187.4    1997
# 2             Star Wars: Episode VII - The Force Awakens   2066.0    2015
# 3                                         Jurassic World   1670.4    2015
# 4                                           The Avengers   1519.6    2012
# 5                                          Furious Seven   1516.0    2015
# 6                                Avengers: Age of Ultron   1405.4    2015
# 7                                The Fate of the Furious   1391.7    2017
# 8           Harry Potter and the Deathly Hallows: Part 2   1341.5    2011
# 9                                                 Frozen   1276.5    2013
# 10                                  Beauty and the Beast   1263.5    2017
# 11                                        Iron Man Three   1215.4    2013
# 12                                               Minions   1163.5    2015
# 13                            Captain America: Civil War   1153.3    2016
# 14                        Transformers: Dark of the Moon   1123.7    2011
# 15         The Lord of the Rings: The Return of the King   1119.9    2003
# 16                                               Skyfall   1108.6    2012
# 17                       Transformers: Age of Extinction   1104.0    2014
# 18                                 The Dark Knight Rises   1084.9    2012
# 19                                         Jurassic Park   1077.5    1993
# 20            Pirates of the Caribbean: Dead Man's Chest   1066.2    2006
# 21                                             Rogue One   1056.1    2016
# 22                                           Toy Story 3   1050.7    2010
# 23           Pirates of the Caribbean: On Stranger Tides   1045.7    2011
# 24                                       Despicable Me 3   1030.6    2017
# 25                                          Finding Dory   1028.6    2016
# 26             Star Wars: Episode I - The Phantom Menace   1027.0    1999
# 27                                   Alice in Wonderland   1025.5    2010
# 28                                              Zootopia   1023.8    2016
# 29                     The Hobbit: An Unexpected Journey   1021.1    2012
# ...                                                  ...        ...   ...
# 16671                                      Green is Gold      0.0    2016
# 16672                                 Farewell Calm Days      0.0    2010
# 16673                                            Illégal      0.0    2010
# 16674          Gottfried Helnwein and the Dreaming Child      0.0    2011
# 16675                            A New Day in Old Sana'a      0.0    2005
# 16676                                              Uncut      0.0    2003
# 16677                                 A People Uncounted      0.0    2011
# 16678                                         Éperdument      0.0    2016
# 16679                                      A Perfect Man      0.0    2013
# 16680                                       Nature Calls      0.0    2012
# 16681                                          Evil Cult      0.0    2003
# 16682                                Gagsters: The Movie      0.0    2011
# 16683                                  Boven is het stil      0.0    2013
# 16684                               Death of a Superhero      0.0    2011
# 16685                                         Algorithms      0.0    2013
# 16686                                         Trojan War      0.0    1997
# 16687                                       Intervention      0.0    2007
# 16688                                           Playback      0.0    2012
# 16689                                            Satanic      0.0    2016
# 16690                            The Innocent Maleficent      0.0    2012
# 16691                                              Alice      0.0    2016
# 16692                                                Aïe      0.0    2000
# 16693                               Amy's Organic Garden      0.0    2015
# 16694                                            Legenda      0.0    2012
# 16695                              Camping Misadventures      0.0    2014
# 16696  The Colonial Parkway: The Foundation of Our Ec...      0.0    2015
# 16697                                 A meg nem érintett      0.0    2012
# 16698                                          Detention      0.0    2010
# 16699                                       Meeting Evil      0.0    2012
# 16700                                        Ground Zero      0.0    2000
#
# [16701 rows x 7 columns]
