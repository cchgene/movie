# %%
import pickle
import pandas as pd

# %%
with open('/home/gene/comments_c3','rb') as f:
    comments_c3 = pickle.load(f)

# %%
comments_c3[0]
# Out:
# {'chname': '萬世魔星',
# ...

# %%
df_comments = pd.DataFrame(comments_c3)
df_comments
# Out:
#             chname                                            comment  \
# 0             萬世魔星  [耶穌基督和祂的時代一向是電影人喜歡的題材由默片年代開始祂和祂身邊的門徒已經不斷登上大銀幕加...
# 1          東方快車謀殺案  [當一部電影經過各種精密計算要有的都有了從票房角度來看必然是萬無一失的從原著讀者所提供的廣大...
# 2         2001太空漫遊  [要選上世紀最偉大的科幻電影太空漫遊相信是毋庸置疑的經典前無古人之作也許它亦是寇比力克一生中...
# 3             機械生活  [機械生活應當被歸類為哪一種電影它是紀錄片也是實驗電影更是聯想式電影當之無愧的代表作之一在電...
# 4              大都會  [攻殼機動隊甫開場晚上的未來世界在霓虹光管和激光影像的映照下少佐飾仰後從摩天大廈一躍以下執行...
# 5              美人魚  [第二十三屆香港電影評論學會大獎最佳導演周星馳美人魚周星馳近十年的合拍片作品長江號的喜劇色彩...
# 6           我不是潘金蓮  [一個細小的縣鎮一位理虧的村婦一群庸碌的官員因為一宗芝麻般的離婚案折騰了十年婦人與官員的糾纏...
# 7             比海還深  [因颱風妮妲襲港令我想起比海還深往後都會在我的颱風系列裡佔據首位對平靜而沉著的一齣家庭片以一...
# 8             哈姆雷特  [熟悉哈姆雷特的讀者影迷當然會放心機在帕斯塔拿如何取捨的心思裡看哈姆雷特視覺具體化的獨白時刻...
# 9            單身動物園  [誰能保證二人走在一起可以直到永遠每次遇到這句話我就有種錯覺以為這是一個我可以隨時愛不愛你的...
# 10           流離者之歌  [去年五月康城影展由高安兄弟擔任主席的評審團在一片爭議聲中把最高榮譽的金棕櫚獎頒發給法國電影...
# 11            山河故人  [黃河的冰塊被炸碎的時候河水的流動從未止息不論是好是壞是美好還是遺憾人生永遠都是處於液態流動...
# ...

# %%
import pandas as pd
df = pd.read_table('/home/gene/imdb/title.basics.tsv',sep='\t')
df.head(5)
# Out:
# /home/gene/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#    isAdult startYear endYear runtimeMinutes                    genres
# 0        0      1894      \N              1         Documentary,Short
# 1        0      1892      \N              5           Animation,Short
# 2        0      1892      \N              4  Animation,Comedy,Romance
# ...

# %%
df = df[df["titleType"] == "movie"]

# %%
df.head(5)
# Out:
#         tconst titleType                   primaryTitle  \
# 8    tt0000009     movie                     Miss Jerry
# 145  tt0000147     movie  The Corbett-Fitzsimmons Fight
# 332  tt0000335     movie          Soldiers of the Cross
# 499  tt0000502     movie                       Bohemios
# 571  tt0000574     movie    The Story of the Kelly Gang
#
#                      originalTitle  isAdult startYear endYear runtimeMinutes  \
# 8                       Miss Jerry        0      1894      \N             45
# 145  The Corbett-Fitzsimmons Fight        0      1897      \N             20
# 332          Soldiers of the Cross        0      1900      \N             \N
# 499                       Bohemios        0      1905      \N            100
# 571    The Story of the Kelly Gang        0      1906      \N             70
#
#                      genres
# 8                   Romance
# 145  Documentary,News,Sport
# 332         Biography,Drama
# 499                      \N
# ...

# %%
comments_merge_genres = df_comments.join(df.set_index('tconst'), on='imdb_id')
comments_merge_genres
# Out:
#             chname                                            comment  \
# 0             萬世魔星  [耶穌基督和祂的時代一向是電影人喜歡的題材由默片年代開始祂和祂身邊的門徒已經不斷登上大銀幕加...
# 1          東方快車謀殺案  [當一部電影經過各種精密計算要有的都有了從票房角度來看必然是萬無一失的從原著讀者所提供的廣大...
# 2         2001太空漫遊  [要選上世紀最偉大的科幻電影太空漫遊相信是毋庸置疑的經典前無古人之作也許它亦是寇比力克一生中...
# 3             機械生活  [機械生活應當被歸類為哪一種電影它是紀錄片也是實驗電影更是聯想式電影當之無愧的代表作之一在電...
# 4              大都會  [攻殼機動隊甫開場晚上的未來世界在霓虹光管和激光影像的映照下少佐飾仰後從摩天大廈一躍以下執行...
# 5              美人魚  [第二十三屆香港電影評論學會大獎最佳導演周星馳美人魚周星馳近十年的合拍片作品長江號的喜劇色彩...
# 6           我不是潘金蓮  [一個細小的縣鎮一位理虧的村婦一群庸碌的官員因為一宗芝麻般的離婚案折騰了十年婦人與官員的糾纏...
# 7             比海還深  [因颱風妮妲襲港令我想起比海還深往後都會在我的颱風系列裡佔據首位對平靜而沉著的一齣家庭片以一...
# 8             哈姆雷特  [熟悉哈姆雷特的讀者影迷當然會放心機在帕斯塔拿如何取捨的心思裡看哈姆雷特視覺具體化的獨白時刻...
# 9            單身動物園  [誰能保證二人走在一起可以直到永遠每次遇到這句話我就有種錯覺以為這是一個我可以隨時愛不愛你的...
# 10           流離者之歌  [去年五月康城影展由高安兄弟擔任主席的評審團在一片爭議聲中把最高榮譽的金棕櫚獎頒發給法國電影...
# 11            山河故人  [黃河的冰塊被炸碎的時候河水的流動從未止息不論是好是壞是美好還是遺憾人生永遠都是處於液態流動...
# ...

# %%
comments_merge_genres = comments_merge_genres.drop(['chname','comment','noComments','titleType','primaryTitle','isAdult','startYear','endYear'],axis=1)

# %%
with open('comments_merge_genres','wb') as f:
    pickle.dump(comments_merge_genres,f)
